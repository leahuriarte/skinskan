# %%
# !pip3 install fastbook
import fastbook
fastbook.setup_book()
import os
os.environ["OMP_NUM_THREADS"] = "1"
# Out:
# Requirement already satisfied: fastbook in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.0.26)
# Requirement already satisfied: datasets in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastbook) (2.4.0)
# Requirement already satisfied: sentencepiece in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastbook) (0.1.96)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastbook) (20.9)
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastbook) (4.21.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastbook) (1.3.0)
# Requirement already satisfied: fastai>=2.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastbook) (2.7.11)
# Requirement already satisfied: graphviz in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastbook) (0.20.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastbook) (2.21.0)
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastbook) (23.0.1)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (3.4.2)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (0.24.2)
# Requirement already satisfied: torch<1.14,>=1.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (1.7.1)
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (5.4.1)
# Requirement already satisfied: fastcore<1.6,>=1.4.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (1.5.28)
# Requirement already satisfied: fastprogress>=0.2.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (1.0.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (0.0.7)
# Requirement already satisfied: pillow>6.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (8.3.1)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (1.7.0)
# Requirement already satisfied: spacy<4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (3.1.1)
# Requirement already satisfied: torchvision>=0.8.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fastai>=2.6->fastbook) (0.8.2)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (1.19.3)
# Requirement already satisfied: xxhash in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (0.8.1)
# Requirement already satisfied: multiprocess in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (0.70.13)
# Requirement already satisfied: aiohttp in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (3.8.1)
# Requirement already satisfied: responses<0.19 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (0.10.15)
# Requirement already satisfied: tqdm>=4.62.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (4.64.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (2022.7.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (8.0.0)
# Requirement already satisfied: dill<0.3.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from datasets->fastbook) (0.3.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->fastbook) (2022.9.24)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->fastbook) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->fastbook) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->fastbook) (2.7)
# Requirement already satisfied: pyparsing>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging->fastbook) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->fastbook) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->fastbook) (2021.1)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers->fastbook) (2022.7.25)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers->fastbook) (0.12.1)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from transformers->fastbook) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets->fastbook) (4.3.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->fastbook) (1.15.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.4.1)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (49.2.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.4)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.11.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (8.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (0.8.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (0.6.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (0.7.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (0.3.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.5)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->datasets->fastbook) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->datasets->fastbook) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->datasets->fastbook) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->datasets->fastbook) (1.7.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->datasets->fastbook) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->datasets->fastbook) (20.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from aiohttp->datasets->fastbook) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib->fastai>=2.6->fastbook) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib->fastai>=2.6->fastbook) (0.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->fastai>=2.6->fastbook) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->fastai>=2.6->fastbook) (1.0.1)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<4->fastai>=2.6->fastbook) (5.1.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from typer<0.4.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2->spacy<4->fastai>=2.6->fastbook) (2.0.1)

# %%
from fastbook import *
from fastai.vision.widgets import *
from pathlib import Path

# %%
path = Path('/Users/Leah/wound/burn')
leafs = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=1),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = leafs.dataloaders(path)

# %%
dls.valid.show_batch(max_n=1, nrows=1)

# %%
leafs = leafs.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = leafs.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/fastai/vision/learner.py:288: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.633161</td>
#       <td>1.096078</td>
#       <td>0.384977</td>
#       <td>01:20</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.183737</td>
#       <td>0.979658</td>
#       <td>0.333333</td>
#       <td>01:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.082416</td>
#       <td>0.871048</td>
#       <td>0.291080</td>
#       <td>01:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.993062</td>
#       <td>0.889966</td>
#       <td>0.295775</td>
#       <td>01:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.902379</td>
#       <td>0.836775</td>
#       <td>0.281690</td>
#       <td>01:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export('burn2.pkl')
path = Path()
learn_inf = load_learner(path/'burn2.pkl')
